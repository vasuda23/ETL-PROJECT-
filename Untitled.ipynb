# %%
import pandas as pd

# %%
df = pd.read_excel("laucntycur14-parse.xlsx")
df.replace(to_replace=df.iloc[45065,6],value=0,inplace=True)
df
# Out:
#              LAUS Code State FIPS Code  County FIPS Code  \
# 0      CN0100100000000              01                 1
# 1      CN0100300000000              01                 3
# 2      CN0100500000000              01                 5
# 3      CN0100700000000              01                 7
# 4      CN0100900000000              01                 9
# ...                ...             ...               ...
# 45061  CN7214500000000              72               145
# 45062  CN7214700000000              72               147
# 45063  CN7214900000000              72               149
# 45064  CN7215100000000              72               151
# 45065  CN7215300000000              72               153
#
#       County Name/State Abbreviation    Period  Labor Force  Employed  \
# 0                 Autauga County, AL    Mar-19        26255     25424
# 1                 Baldwin County, AL    Mar-19        97617     94468
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45066 entries, 0 to 45065
# Data columns (total 9 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   LAUS Code                       45066 non-null  object
#  1   State FIPS Code                 45066 non-null  object
#  2   County FIPS Code                45066 non-null  int64
#  3   County Name/State Abbreviation  45066 non-null  object
#  4   Period                          45066 non-null  object
#  5   Labor Force                     45066 non-null  object
#  6   Employed                        45066 non-null  object
#  7   Unemployed                      45066 non-null  object
#  8   Unemployment Rate (%)           45066 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 3.1+ MB

# %%
df["LAUS Code"].value_counts()
# Out:
# CN4602500000000    14
# CN0800700000000    14
# CN3901900000000    14
# CN2606900000000    14
# CN3700900000000    14
#                    ..
# CN2816300000000    14
# CN0108900000000    14
# CN1811300000000    14
# CN2121100000000    14
# CN4839700000000    14
# Name: LAUS Code, Length: 3219, dtype: int64

# %%
laus_dict= dict()
for code in df["LAUS Code"].unique():
    laus_dict[code] = df.loc[df["LAUS Code"] == code,:]
laus_dict
# Out:
# {'CN0100100000000':              LAUS Code State FIPS Code  County FIPS Code  \
#  0      CN0100100000000              01                 1
#  3219   CN0100100000000              01                 1
#  6438   CN0100100000000              01                 1
#  9657   CN0100100000000              01                 1
#  12876  CN0100100000000              01                 1
#  16095  CN0100100000000              01                 1
#  19314  CN0100100000000              01                 1
#  22533  CN0100100000000              01                 1
#  25752  CN0100100000000              01                 1
#  28971  CN0100100000000              01                 1
#  32190  CN0100100000000              01                 1
#  35409  CN0100100000000              01                 1
#  38628  CN0100100000000              01                 1
#  41847  CN0100100000000              01                 1
#
#        County Name/State Abbreviation    Period Labor Force Employed  \
# ...

# %%
df.describe()
# Out:
#        County FIPS Code   Labor Force      Employed     Unemployed  \
# count      45066.000000  4.506600e+04  4.506600e+04   45066.000000
# mean         102.952470  5.085796e+04  4.860028e+04    2257.682932
# std          106.681065  1.672536e+05  1.596453e+05    9694.218860
# min            1.000000  0.000000e+00  0.000000e+00       0.000000
# 25%           35.000000  4.856000e+03  4.607250e+03     204.000000
# 50%           79.000000  1.137850e+04  1.087350e+04     509.000000
# 75%          133.000000  3.099675e+04  2.961975e+04    1383.750000
# max          840.000000  5.222823e+06  4.984604e+06  968385.000000
#
#        Unemployment Rate (%)
# count           45066.000000
# mean                4.729095
# std                 3.186432
# min                 0.000000
# 25%                 3.000000
# 50%                 3.800000
# 75%                 5.100000
# max                41.200000

# %%
df.to_csv("lau-clean.csv")

# %%
#qcew
df = pd.read_excel("allhlcn19.xlsx")
df
# Out:
#       Area\nCode   St  Cnty  Own  NAICS  Year Qtr Area Type St Name  \
# 0          US000   US   0.0    0     10  2019   A    Nation     NaN
# 1          US000   US   0.0    1     10  2019   A    Nation     NaN
# 2          US000   US   0.0    2     10  2019   A    Nation     NaN
# 3          US000   US   0.0    3     10  2019   A    Nation     NaN
# 4          US000   US   0.0    5     10  2019   A    Nation     NaN
# ...          ...  ...   ...  ...    ...   ...  ..       ...     ...
# 62847      C4974  NaN   NaN    5   1024  2019   A       MSA     NaN
# 62848      C4974  NaN   NaN    5   1025  2019   A       MSA     NaN
# 62849      C4974  NaN   NaN    5   1026  2019   A       MSA     NaN
# 62850      C4974  NaN   NaN    5   1027  2019   A       MSA     NaN
# 62851      C4974  NaN   NaN    5   1029  2019   A       MSA     NaN
#
#                Area           Ownership  \
# 0        U.S. TOTAL       Total Covered
# 1        U.S. TOTAL  Federal Government
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62852 entries, 0 to 62851
# Data columns (total 20 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Area
# Code                                      62852 non-null  object
#  1   St                                             56129 non-null  object
#  2   Cnty                                           56129 non-null  float64
#  3   Own                                            62852 non-null  int64
#  4   NAICS                                          62852 non-null  int64
#  5   Year                                           62852 non-null  int64
#  6   Qtr                                            62852 non-null  object
#  7   Area Type                                      62852 non-null  object
#  8   St Name                                        56111 non-null  object
# ...

# %%
df = pd.read_excel("allhlcn19.xlsx",sheet_name="US_PR_VI")
df
